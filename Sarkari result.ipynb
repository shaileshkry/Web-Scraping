# %%
import requests as rq
from bs4 import BeautifulSoup as bsp
import re

# %%
link='https://www.sarkariresult.com/latestjob/'

# %%
res=rq.get(link)
res
# Out:
# <Response [200]>

# %%
html=res.text

# %%
soup=bsp(html,'html.parser')

# %%
soup.find('li')
# Out:
# <li><a href="https://www.sarkariresult.com/">Home</a></li>

# %%
b=str(soup.find(id='post'))
pattern='href=(.*)target'
link=re.findall(pattern,b)[0][1:-2]
link
# Out:
# 'https://www.sarkariresult.com/2024/nclcil-asst-foreman-jan24/'

# %%
res=rq.get(link)
html=res.text
soup=bsp(html,'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en"><head>
# <title>
# NCL CIL Assistant Foreman Online Form 2024 for 150 Post</title>
# <meta content="Apply Online Northern Coalfield Limited CIL Assistant Foreman Trainee Recruitment 2024, Check Eligibility, Exam Date, Download Syllabus and Notification, How to Apply and More." name="description"/>
# <meta content="NCL CIL Recruitment 2024, NCL CIL Assistant Foreman Online Form 2024, NCL CIL Assistant Foreman Notification 2024, Sarkari Result" name="keywords"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <link href="https://www.sarkariresult.com/2024/nclcil-asst-foreman-jan24/" rel="canonical"/>
# <script type="application/ld+json">
# {
#   "@context": "https://schema.org",
#   "@type": "Article",
#   "mainEntityOfPage": {
#     "@type": "WebPage",
#     "@id": "https://www.sarkariresult.com/2024/nclcil-asst-foreman-jan24/"
#   },
#   "headline": "NCL CIL Assistant Foreman Online Form 2024 for 150 Post",
#   "description": "Apply Online Northern Coalfield Limited CIL Assistant Foreman Trainee Recruitment 2024, Check Eligibility, Exam Date, Download Syllabus and Notification, How to Apply and More.",
#   "image": "https://www.sarkariresult.com/upload/nclcilasstforemanjan24.jpg",
#   "author": {
#     "@type": "Organization",
#     "name": "Sarkari Result",
#     "url": "https://www.sarkariresult.com/"
#   },
#   "publisher": {
#     "@type": "Organization",
#     "name": "SarkariResult.Com",
#     "logo": {
#       "@type": "ImageObject",
#       "url": "https://www.sarkariresult.com/images/logo-new.png"
#     }
#   },
#   "datePublished": "2024-01-15",
#   "dateModified": "2024-01-15"
# }
# </script>
# <!-- Open Graph / Facebook -->
# <meta content="website" property="og:type"/>
# <meta content="https://www.sarkariresult.com/2024/nclcil-asst-foreman-jan24/" property="og:url"/>
# <meta content="NCL CIL Assistant Foreman Online Form 2024 for 150 Post" property="og:title"/>
# <meta content="Apply Online Northern Coalfield Limited CIL Assistant Foreman Trainee Recruitment 2024, Check Eligibility, Exam Date, Download Syllabus and Notification, How to Apply and More." property="og:description"/>
# <meta content="https://www.sarkariresult.com/upload/nclcilasstforemanjan24.jpg" property="og:image"/>
# <!-- Twitter -->
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="https://www.sarkariresult.com/2024/nclcil-asst-foreman-jan24/" property="twitter:url"/>
# <meta content="NCL CIL Assistant Foreman Online Form 2024 for 150 Post" property="twitter:title"/>
# <meta content="Apply Online Northern Coalfield Limited CIL Assistant Foreman Trainee Recruitment 2024, Check Eligibility, Exam Date, Download Syllabus and Notification, How to Apply and More." property="twitter:description"/>
# <meta content="https://www.sarkariresult.com/upload/nclcilasstforemanjan24.jpg" property="twitter:image"/>
# </head>
# <body style="background-color:#FFFFFF">
# <link href="https://www.sarkariresult.com/style2.css" rel="stylesheet" type="text/css"/>
# <!--<meta name="viewport" content="width=device-width, initial-scale=1">-->
# <meta content="width=device-width, initial-scale=0.4, maximum-scale=0.4" name="viewport"/>
# <div align="center">
# <div style="height:auto; width:1000px; margin:0">
# <div id="header" onclick="" style="cursor: pointer;">
# <div id="head-title">
# <div id="logo">
# <img alt="SarkariResult" height="70px" src="https://www.sarkariresult.com/images/logo-new.png" style="float:left" width="60px"/>
# </div>
# <font size="+4">SARKARI RESULT</font>
# <br/>
# <font size="+2">WWW.SARKARIRESULT.COM</font>
# </div>
# </div>
# <div id="hmenu">
# <ul class="hmenu">
# <li>
# <a class="parent" href="https://www.sarkariresult.com">
# <span>Home</span>
# </a>
# </li>
# <li>
# <a class="parent" href="https://www.sarkariresult.com/latestjob/">
# <span>Latest Jobs</span>
# </a>
# </li>
# <li>
# <a class="parent" href="https://www.sarkariresult.com/result/">
# <span>Result</span>
# </a>
# </li>
# <li>
# <a class="parent" href="https://www.sarkariresult.com/admitcard/">
# <span>Admit Card</span>
# </a>
# </li>
# <li>
# <a class="parent" href="https://www.sarkariresult.com/answerkey/">
# <span>Answer Key</span>
# </a>
# </li>
# <li>
# <a class="parent" href="https://www.sarkariresult.com/admission/">
# <span>Admissions</span>
# </a>
# </li>
# <li>
# <a class="parent" href="https://www.sarkariresult.com/syllabus/">
# <span>Syllabus</span>
# </a>
# </li>
# <li>
# <a class="parent" href="https://www.sarkariresult.com/search/">
# <span>Search</span>
# </a>
# </li>
# <li>
# <a class="parent" href="https://play.google.com/store/apps/details?id=com.app.app14f269771c01">
# <span>Android App</span>
# </a>
# </li>
# <li>
# <a class="parent" href="https://www.sarkariresult.com/contactus/">
# <span>Contact Us</span>
# </a>
# </li>
# </ul>
# </div>
# <br/>
# <center><script async="" crossorigin="anonymous" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js?client=ca-pub-9222595088627935"></script>
# <!-- 970x250 head 291123 -->
# <ins class="adsbygoogle" data-ad-client="ca-pub-9222595088627935" data-ad-slot="2315344597" style="display:inline-block;width:970px;height:250px"></ins>
# <script>
#      (adsbygoogle = window.adsbygoogle || []).push({});
# </script></center>
# <br/>
# <script data-cfasync="false" type="text/javascript">(function(w, d) { var s = d.createElement('script'); s.src = '//cdn.adpushup.com/42768/adpushup.js'; s.crossOrigin='anonymous'; s.type = 'text/javascript'; s.async = true; (d.getElementsByTagName('head')[0] || d.getElementsByTagName('body')[0]).appendChild(s); })(window, document);</script>
# <script data-cfasync="false" type="text/javascript">(function(w, d) { var s = d.createElement("script"); s.src = "//delivery.adrecover.com/43603/adRecover.js"; s.type = "text/javascript"; s.async = true; (d.getElementsByTagName("head")[0] || d.getElementsByTagName("body")[0]).appendChild(s); })(window, document);</script>
# <style>
# table h1 {
#     display: block;
#     font-size: 22px;
#     color: #0F3063;
#     margin-left: 0;
#     margin-right: 0;
# }
# td { font-size: 20px;}
#     h2 { font-size: 28px;}
#      li{ font-size: 21px;
#         margin-left: 10px;
#     }
# @media (max-width: 991px){
#     td { font-size: 28px;}
#      h2 { font-size: 25px;}
#     }
# @media (max-width: 767px){
#      h2 { font-size: 32px;}
#     td { font-size: 30px;}
#     ul li{ font-size: 30px;}
# }
# </style>
# <table align="center" width="100%"></table>
# <tr valign="top"></tr>
# <td>
# <div align="left"></div>
# <h2><table align="center" style="margin-left:10px"></table>
# <tr>
# <td align="left" style="font-weight:bold; color:#FF0033" valign="top">Name of Post: </td>
# <td align="left" valign="top"><h1>Northern Coalfield Limited NCLCIL Assistant Foreman Recruitment 2024 Apply Online for 150 Post</h1></td>
# </tr>
# <tr>
# <td "="" align="left" style="font-weight:bold; color:#FF0033" valign="top">Post Date / Update:</td>
# <td align="left" valign="top">15 January 2024 | 03:15 PM</td>
# </tr>
# <tr>
# <td align="left" style="font-weight:bold; color:#FF0033" valign="top">Short Information : </td>
# <td align="left" valign="top"><a href="https://www.nclcil.in/" target="_blank" title="NCL"><span style="color: #ff0000;">Northern Coalfield Limited NCLCIL</span></a> has relased Assistant Foreman Trainee Recruitment 2024. Those candidates who are interested in this NCL CIL Assistant Foreman Trainee recruitment can apply online from 15 January 2024 to 05 February 2024. Read the notification for recruitment eligibility, post information, selection procedure, age limit, pay scale and all other information.
# </td>
# </tr>
#
# <br/>
# <div>
# <div id="v-sarkariresult"></div><script data-cfasync="false">(function(v,d,o,ai){ai=d.createElement('script');ai.defer=true;ai.async=true;ai.src=v.location.protocol+o;d.head.appendChild(ai);})(window, document, '//a.vdo.ai/core/v-sarkariresult/vdo.ai.js');</script></div>
# <br/>
# <table border="1" cellpadding="0" cellspacing="0" width="706">
# <tbody>
# <tr>
# <td colspan="6" valign="top" width="706">
# <h2 align="center"><span style="color: #ff00ff;"><b>Northern Coalfield Limited (NCL)</b></span><b></b></h2>
# <h2 align="center"><span style="color: #008000;"><b>NCL CIL Assistant Foreman (Trainee) Recruitment 2024</b></span></h2>
# <h2 align="center"><span style="color: #ff00ff;"><b>NCLCIL Assistant Foreman Exam 2024: Short Details of Notification</b></span></h2>
# <h2 align="center"><span style="color: #ff0000;"><b><a href="https://www.sarkariresult.com/" target="_blank" title="Sarkari Result 2024"><span style="color: #ff0000;">WWW.SARKARIRESULT.COM</span></a></b></span><b></b></h2>
# </td>
# </tr>
# <tr>
# <td colspan="4" valign="top" width="357">
# <h2 align="center"><span style="color: #008000;"><b>Important Dates </b></span><b> </b></h2>
# <ul>
# <li>Application Begin <b>: 15/01/2024</b></li>
# <li>Last Date for Apply Online <b>: <span style="color: #ff0000;">05/02/2024</span> </b></li>
# <li>Pay the Exam Last Date : <b>05/02/2024</b></li>
# <li>Exam Date<b>:  As per Schedule</b></li>
# <li>Admit Card Available <b>: Before Exam</b></li>
# </ul>
# </td>
# <td colspan="2" valign="top" width="349">
# <h2 align="center"><span style="color: #008000;"><b>Application Fee</b></span><b></b></h2>
# <ul>
# <li>General / OBC / EWS : <b>1180/-</b></li>
# <li>SC / ST / PH : <b>0/- </b></li>
# <li>Pay the Exam Fee Through Debit Card / Credit Card / Net Banking Only.</li>
# </ul>
#  </td>
# </tr>
# <tr>
# <td colspan="6" valign="top" width="706">
# <h2 align="center"><span style="color: #008000;"><b>NCL Assistant Foreman Notification 2024 : <span style="color: #ff00ff;">Age Limit as on </span></b><span style="color: #ff00ff;"><b>05/02/2024</b></span></span><b></b></h2>
# <ul>
# <li>Minimum Age :<b> 18 Years.</b></li>
# <li>Maximum Age :<b> 30 Years.</b></li>
# <li>Age Relaxation As per Northern Coal Field NCL Assistant Foreman Trainee 2024 Recruitment Rules.</li>
# </ul>
# </td>
# </tr>
# <tr>
# <td colspan="6" valign="top" width="706">
# <h2 align="center"><span style="color: #ff00ff;"><b>NCL Assistant Foreman Recruitment 2024 : <span style="color: #008000;">Vacancy Details Total : 150 Post</span></b></span></h2>
# </td>
# </tr>
# <tr>
# <td valign="top" width="257">
# <p align="center"><b>Post Name</b></p>
# </td>
# <td colspan="4" valign="top" width="142">
# <p align="center"><b>Total Post</b></p>
# </td>
# <td valign="top" width="307">
# <p align="center"><b>NCL Assistant Foreman Eligibility</b></p>
# </td>
# </tr>
# <tr>
# <td valign="top" width="257">
# <p align="center">Assistant Foreman (E&amp;T) (Trainee) Grade-C</p>
# </td>
# <td colspan="4" valign="top" width="142">
# <p align="center">09</p>
# </td>
# <td rowspan="3" valign="top" width="307">
# <ul>
# <li>Class 10th with Diploma in Engineering (Polytechnic) in Related Trade.</li>
# <li>More Eligibility Details Read the Notification.</li>
# </ul>
# </td>
# </tr>
# <tr>
# <td valign="top" width="257">
# <p align="center">Assistant Foreman (Mechanical) (Trainee) Grade-C</p>
# </td>
# <td colspan="4" valign="top" width="142">
# <p align="center">59</p>
# </td>
# </tr>
# <tr>
# <td valign="top" width="257">
# <p align="center">Assistant Foreman (Electrical) (Trainee) Grade-C</p>
# </td>
# <td colspan="4" valign="top" width="142">
# <p align="center">82</p>
# </td>
# </tr>
# <tr>
# <td colspan="6" valign="top" width="706">
# <center><script async="" crossorigin="anonymous" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js?client=ca-pub-9222595088627935"></script>
# <!-- 300 x 250 mar 23 -->
# <ins class="adsbygoogle" data-ad-client="ca-pub-9222595088627935" data-ad-slot="5663166237" style="display:inline-block;width:300px;height:250px"></ins>
# <script>
#      (adsbygoogle = window.adsbygoogle || []).push({});
# </script></center>
# <h2 align="center"><span style="color: #008000;"><b>How to Fill NCL CIL Assistant Foreman Exam 2024 Online Form</b></span></h2>
# <ul>
# <li>Northern Coalfield Limited NCL Assistant Foreman Latest Recruitment 2024for the Post of Asst Foreman Trainee Post Can Apply Between  <b>15/01/2024 to 05/02/2024.</b></li>
# <li>Candidate Read the Notification Before Apply the Vacancies Application Form in Govt. Jobs of NCL Assistant Foreman Trainee NCL CIL Career Recruitment Online Form 2024.</li>
# <li>Kindly Check and Collect the All Document - Eligibility, ID Proof, Address Details, Basic Details.</li>
# <li>Kindly Ready Scan Document Related to Recruitment Form - Photo, Sign, ID Proof, Etc.</li>
# <li>Before Apply Online / Submit Application Form Must Check the Preview and All Column Carefully.</li>
# <li>Take A Print Out of Final Submitted Form.</li>
# </ul>
# </td>
# </tr>
# <tr>
# <td colspan="6" valign="top" width="706">
# <h2 align="center"><span style="color: #ff00ff;"><b>Interested Candidate Can Read the Full Notification Before Apply Online.</b></span><b></b></h2>
# </td>
# </tr>
# <tr>
# <td colspan="6" valign="top" width="706">
# <h2 align="center"><span style="color: #008000;"><b>Download Mobile Apps for the Latest Updates</b></span><b></b></h2>
# </td>
# </tr>
# <tr>
# <td colspan="2" valign="top" width="338">
# <h2 align="center"><b><a href="https://play.google.com/store/apps/details?id=com.app.app14f269771c01" target="_blank" title="Sarkari Result Android Apps">Android Apps</a></b></h2>
# </td>
# <td colspan="4" valign="top" width="368">
# <h2 align="center"><b><a href="https://play.google.com/store/apps/details?id=com.app.app14f269771c01" target="_blank" title="Apple IOS Apps">Apple IOS Apps</a></b></h2>
# </td>
# </tr>
# <tr>
# <td colspan="6" valign="top" width="706">
# <h2 align="center"><span style="color: #008000;"><b>Some Useful Important Links</b></span><b></b></h2>
# </td>
# </tr>
# <tr>
# <td colspan="3" valign="top" width="352">
# <h2 align="center"><span style="color: #ff00ff;"><b>Apply Online</b></span><b></b></h2>
# </td>
# <td colspan="3" valign="top" width="354">
# <h2 align="center"><b><a href="https://cdn.digialm.com/EForms/configuredHtml/1258/86489/Index.html" target="_blank" title="NCL Assistant Foreman Registration 2024">Click Here</a></b></h2>
# </td>
# </tr>
# <tr>
# <td colspan="3" valign="top" width="352">
# <h2 align="center"><span style="color: #ff00ff;"><b>Download Notification</b></span><b></b></h2>
# </td>
# <td colspan="3" valign="top" width="354">
# <h2 align="center"><a href="https://www.nclcil.in/Content/nclcil.in/Document/772Detailed%20Supervisory%20Employment%20Notification%20-%20English.pdf" target="_blank" title="NCL CIL Assistant Foreman Notification 2024"><b>Click Here</b></a></h2>
# </td>
# </tr>
# <tr>
# <td colspan="3" valign="top" width="352">
# <h2 align="center"><span style="color: #ff00ff;"><b>Download Syllabus</b></span></h2>
# </td>
# <td colspan="3" valign="top" width="354">
# <h2 align="center"><a href="https://www.sarkariresults.org.in/wp-content/uploads/2024/01/NCL-Assistant-Foreman-Syllabus_watermark.pdf" target="_blank" title="NCL CIL Assistant Foreman Syllabus 2024"><b>Click Here</b></a></h2>
# </td>
# </tr>
# <tr>
# <td colspan="3" valign="top" width="352">
# <h2 align="center"><span style="color: #008080;"><b>Resume CV Maker, Bio Data Maker, Image Resizer and More Tools</b></span></h2>
# </td>
# <td colspan="3" valign="top" width="354">
# <h2 align="center"><a href="https://sarkariresult.tools/" target="_blank" title="Sarkari Result Tools"><b>Sarkari Result Tools</b></a></h2>
# </td>
# </tr>
# <tr>
# <td colspan="3" valign="top" width="352">
# <h2 align="center"><span style="color: #008080;"><b>Join Sarkari Result Channel</b></span></h2>
# </td>
# <td colspan="3" valign="top" width="354">
# <h2 align="center"><a href="https://t.me/sarkari" target="_blank" title="Sarkari Result Telegram Channel"><b>Telegram</b></a><b> | </b><a href="https://whatsapp.com/channel/0029Va5IElwBlHpVBd6i5a18" target="_blank" title="Sarkari Result Free Whatsapp Channel Join"><b>WhatsApp</b></a></h2>
# </td>
# </tr>
# <tr>
# <td colspan="3" valign="top" width="352">
# <h2 align="center"><span style="color: #ff00ff;"><b>Official Website</b></span><b></b></h2>
# </td>
# <td colspan="3" valign="top" width="354">
# <h2 align="center"><b><a href="https://www.nclcil.in/" target="_blank" title="NCL CIL Official Website for Latest Jobs 2023">NCL CIL Official Website</a></b></h2>
# </td>
# </tr>
# <tr>
# <td colspan="6" valign="top" width="706">
# <h2 align="center"><span style="color: #008000;"><b>Find More Latest Updates</b></span><b></b></h2>
# <h2 align="center"><b><a href="https://www.sarkariresult.com/delhi/dsssb-spa-pa-jja-01-2024/" target="_blank" title="DSSSB Advt No 05/2023 Notification Download">DSSSB SPA, PA, JJA Recruitment 2024</a></b></h2>
# <h2 align="center"><b><a href="https://www.sarkariresult.com/jharkhand/jssc-constable-jcce2023/" target="_blank" title="JSSC Constable Notification PDF 2023">Jharkhand SSC Constable Recruitment 2024</a></b></h2>
# <h2 align="center"><a href="https://www.sarkariresult.com/rpsc/rpsc-asst-prof-sanskrit-jan24/" target="_blank" title="Rajasthan RPSC Assistant Professor"><b>Rajasthan Assistant Professor Recruitment 2024</b></a></h2>
# <h2 align="center"><a href="https://www.sarkariresult.com/railway/nwr-rrc-jaipur-apprentices-jan24/" target="_blank" title="Apply Online Railway Apprentices 2024"><b>Railway NWR Apprentices Recruitment 2024</b></a></h2>
# </td>
# </tr>
# </tbody>
# </table>
# <center><script>(function(d, s, id) {
# var js, fjs = d.getElementsByTagName(s)[0];
# if (d.getElementById(id)) return;
# js = d.createElement(s); js.id = id;
# js.src = "https://connect.facebook.net/en_US/sdk.js#xfbml=1&version=v3.0";
# fjs.parentNode.insertBefore(js, fjs);
# }(document, 'script', 'facebook-jssdk'));</script>
# <div class="fb-share-button" data-href="https://www.sarkariresult.com/2024/nclcil-asst-foreman-jan24/" data-layout="button_count">
# </div>
# <a class="twitter-follow-button" data-show-count="false" href="https://twitter.com/sarkari_result?ref_src=twsrc%5Etfw">Follow @sarkari_result</a><script async="" charset="utf-8" src="https://platform.twitter.com/widgets.js"></script></center>
# <div align="center" id="image" style="margin-top: 20px">
# <img alt="Sarkari Result NCL CIL Assistant Foreman Online Form 2024" height="200" src="/upload/nclcilasstforemanjan24.jpg" width="500px"/>
# </div>
#
#
# </h2></td></div>
#
# <td>
# <div>
# <iframe allowtransparency="true" frameborder="1" scrolling="no" src="//www.facebook.com/plugins/likebox.php?href=http%3A%2F%2Fwww.facebook.com%2Fpages%2Fsarkariresultcom%2F499890650057530&amp;width=292&amp;height=170&amp;show_faces=true&amp;colorscheme=light&amp;stream=false&amp;show_border=false&amp;header=false" style="border:1px; overflow:hidden; width:232px; height:258px"></iframe>
# </div>
# <div>
# <script async="" crossorigin="anonymous" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js?client=ca-pub-9222595088627935"></script>
# <!-- Right221123 -->
# <ins class="adsbygoogle" data-ad-client="ca-pub-9222595088627935" data-ad-format="auto" data-ad-slot="5789452107" data-full-width-responsive="true" style="display:block"></ins>
# <script>
#      (adsbygoogle = window.adsbygoogle || []).push({});
# </script>
# </div>
# </td>
#
#
# </div>
# <div align="center" id="footer">
# <tr>
# <td align="left" width="100%">
# <div align="center" id="footer">
# <left>
# <div id="copy">Welcome to this official website of Sarkari Result<br/>There are many websites similar to the name of Sarkari Result, so you have to be careful, to open the real SarkariResult website, just open WWW.SARKARIRESULT.COM and after SarkariResult .Com must be checked, for all kinds of updates related to jobs. For you our Mobile App which is also available for free on Google Play, Apple Store and Microsoft Store, as well as you can connect with us on our social media accounts: Twitter, Facebook, Instagram, Koo, Telegram , available on Youtube. <br/></div>
# <left>
# <div class="_ap_apex_ad" id="a4feaaf0-58d1-44ea-958a-78c53b8002a8">
# <script>
# 		var adpushup = window.adpushup = window.adpushup || {};
# 		adpushup.que = adpushup.que || [];
# 		adpushup.que.push(function() {
# 			adpushup.triggerAd("a4feaaf0-58d1-44ea-958a-78c53b8002a8");
# 		});
# 	</script>
# </div>
# </left>
# <div id="copy"> © Copyright 2024-2025 at www.sarkariresult.com
# 		<br>For advertising in this website contact us sarkariresult@gmail.com<br/><br/></br></div>
# <a href="https://www.dmca.com/Protection/Status.aspx?ID=c81d92e5-9e14-4471-b080-8d86f5167345" title="DMCA"> <img alt="DMCA.com" src="https://images.dmca.com/Badges/dmca_protected_sml_120e.png?ID=c81d92e5-9e14-4471-b080-8d86f5167345"/></a>
# <div align="center" style="margin-bottom:10px"><font color="#FF0000" size="-1"><b>Disclaimer : </b>The Examination Results / Marks published in this Website is only for the immediate Information to the Examinees an does not to be a constitute to be a Legal Document. While all efforts have been made to make the Information available on this Website as Authentic as possible. We are not responsible for any Inadvertent Error that may have crept in the Examination Results / Marks being published in this Website nad for any loss to anybody or anything caused by any Shortcoming, Defect or Inaccuracy of the Information on this Website.</font></div>
# </left></div>
# </td>
# </tr>
# </div></body>
# </html>

# %%
soup.find('title').text[2:]
# Out:
# 'NCL CIL Assistant Foreman Online Form 2024 for 150 Post'

# %%
j=0
title=soup.find('title').text[2:]
pdf=title +"\n"
print(soup.find('title').text[2:])

for i in soup.find_all('li') or soup.find_all('h1') or soup.find_all('h2') or soup.find_all('b'):
    if j in range(10,30):
        print(i.text)
        pdf+=str(i.text)+'\n'
    j+=1
# Out:
# NCL CIL Assistant Foreman Online Form 2024 for 150 Post
# Application Begin : 15/01/2024
# Last Date for Apply Online : 05/02/2024
# Pay the Exam Last Date : 05/02/2024
# Exam Date:  As per Schedule
# Admit Card Available : Before Exam
# General / OBC / EWS : 1180/-
# SC / ST / PH : 0/-
# Pay the Exam Fee Through Debit Card / Credit Card / Net Banking Only.
# Minimum Age : 18 Years.
# Maximum Age : 30 Years.
# Age Relaxation As per Northern Coal Field NCL Assistant Foreman Trainee 2024 Recruitment Rules.
# Class 10th with Diploma in Engineering (Polytechnic) in Related Trade.
# More Eligibility Details Read the Notification.
# Northern Coalfield Limited NCL Assistant Foreman Latest Recruitment 2024for the Post of Asst Foreman Trainee Post Can Apply Between  15/01/2024 to 05/02/2024.
# Candidate Read the Notification Before Apply the Vacancies Application Form in Govt. Jobs of NCL Assistant Foreman Trainee NCL CIL Career Recruitment Online Form 2024.
# Kindly Check and Collect the All Document - Eligibility, ID Proof, Address Details, Basic Details.
# Kindly Ready Scan Document Related to Recruitment Form - Photo, Sign, ID Proof, Etc.
# Before Apply Online / Submit Application Form Must Check the Preview and All Column Carefully.
# Take A Print Out of Final Submitted Form.

# %%
print(pdf)
# Out:
# NCL CIL Assistant Foreman Online Form 2024 for 150 Post
# Application Begin : 15/01/2024
# Last Date for Apply Online : 05/02/2024
# Pay the Exam Last Date : 05/02/2024
# Exam Date:  As per Schedule
# Admit Card Available : Before Exam
# General / OBC / EWS : 1180/-
# SC / ST / PH : 0/-
# Pay the Exam Fee Through Debit Card / Credit Card / Net Banking Only.
# Minimum Age : 18 Years.
# Maximum Age : 30 Years.
# Age Relaxation As per Northern Coal Field NCL Assistant Foreman Trainee 2024 Recruitment Rules.
# Class 10th with Diploma in Engineering (Polytechnic) in Related Trade.
# More Eligibility Details Read the Notification.
# Northern Coalfield Limited NCL Assistant Foreman Latest Recruitment 2024for the Post of Asst Foreman Trainee Post Can Apply Between  15/01/2024 to 05/02/2024.
# Candidate Read the Notification Before Apply the Vacancies Application Form in Govt. Jobs of NCL Assistant Foreman Trainee NCL CIL Career Recruitment Online Form 2024.
# Kindly Check and Collect the All Document - Eligibility, ID Proof, Address Details, Basic Details.
# Kindly Ready Scan Document Related to Recruitment Form - Photo, Sign, ID Proof, Etc.
# Before Apply Online / Submit Application Form Must Check the Preview and All Column Carefully.
# Take A Print Out of Final Submitted Form.
