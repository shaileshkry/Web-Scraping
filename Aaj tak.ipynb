# %%
import requests as rq
from bs4 import BeautifulSoup as bsp
import re

# %%
res=rq.get('https://www.aajtak.in/bihar')
res
# Out:
# <Response [200]>

# %%
html=res.text

# %%
soup=bsp(html,'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="hi">
# <head>
# <title>Bihar News: Bihar (बिहार) Samachar, Latest Bihar Breaking News Khabar in Hindi, Bihar न्यूज़ - Aaj Tak</title>
# ...

# %%
soup.find(class_='widget-listing-content-section')
# Out:
# <div class="widget-listing-content-section"> <h2><a href="https://www.aajtak.in/bihar/story/newly-married-woman-strangled-to-death-in-bihar-absconds-after-leaving-her-in-laws-house-lclcn-1859172-2024-01-14" title="बिहार: नवविवाहिता की गला दबाकर हत्या, ससुराल वाले घर छोड़कर फरार">बिहार: नवविवाहिता की गला दबाकर हत्या, ससुराल वाले घर छोड़कर फरार</a></h2> <h5>14 जनवरी 2024</h5> <p>पटना में एक नवविवाहित की गला दबाकर हत्या कर दी गई. मृतक के परिजनों ने आरोप लगाया कि रविवार को उन्हें सूचना मिली कि उनकी बेटी की मौत हो गई है, जबकि शनिवार की रात में ही बेटी से बात हुई थी. वह बहुत रो रही थी. मृतक के परिजन जब दामाद के घर पहुंचे, तो ससुराल के सभी सदस्य घर छोड़ कर फरार हो गए थे.</p> </div>

# %%
soup.find(class_='widget-listing-content-section').text
# Out:
# ' बिहार: नवविवाहिता की गला दबाकर हत्या, ससुराल वाले घर छोड़कर फरार 14 जनवरी 2024 पटना में एक नवविवाहित की गला दबाकर हत्या कर दी गई. मृतक के परिजनों ने आरोप लगाया कि रविवार को उन्हें सूचना मिली कि उनकी बेटी की मौत हो गई है, जबकि शनिवार की रात में ही बेटी से बात हुई थी. वह बहुत रो रही थी. मृतक के परिजन जब दामाद के घर पहुंचे, तो ससुराल के सभी सदस्य घर छोड़ कर फरार हो गए थे. '

# %%
for i in soup.find_all(class_='widget-listing-content-section'):
    print(i)
# Out:
# <div class="widget-listing-content-section"> <h2><a href="https://www.aajtak.in/bihar/story/newly-married-woman-strangled-to-death-in-bihar-absconds-after-leaving-her-in-laws-house-lclcn-1859172-2024-01-14" title="बिहार: नवविवाहिता की गला दबाकर हत्या, ससुराल वाले घर छोड़कर फरार">बिहार: नवविवाहिता की गला दबाकर हत्या, ससुराल वाले घर छोड़कर फरार</a></h2> <h5>14 जनवरी 2024</h5> <p>पटना में एक नवविवाहित की गला दबाकर हत्या कर दी गई. मृतक के परिजनों ने आरोप लगाया कि रविवार को उन्हें सूचना मिली कि उनकी बेटी की मौत हो गई है, जबकि शनिवार की रात में ही बेटी से बात हुई थी. वह बहुत रो रही थी. मृतक के परिजन जब दामाद के घर पहुंचे, तो ससुराल के सभी सदस्य घर छोड़ कर फरार हो गए थे.</p> </div>
# ...

# %%
for i in soup.find_all(class_='widget-listing-content-section'):
    print('*'*20)
    print(i)
# Out:
# ********************
# <div class="widget-listing-content-section"> <h2><a href="https://www.aajtak.in/bihar/story/newly-married-woman-strangled-to-death-in-bihar-absconds-after-leaving-her-in-laws-house-lclcn-1859172-2024-01-14" title="बिहार: नवविवाहिता की गला दबाकर हत्या, ससुराल वाले घर छोड़कर फरार">बिहार: नवविवाहिता की गला दबाकर हत्या, ससुराल वाले घर छोड़कर फरार</a></h2> <h5>14 जनवरी 2024</h5> <p>पटना में एक नवविवाहित की गला दबाकर हत्या कर दी गई. मृतक के परिजनों ने आरोप लगाया कि रविवार को उन्हें सूचना मिली कि उनकी बेटी की मौत हो गई है, जबकि शनिवार की रात में ही बेटी से बात हुई थी. वह बहुत रो रही थी. मृतक के परिजन जब दामाद के घर पहुंचे, तो ससुराल के सभी सदस्य घर छोड़ कर फरार हो गए थे.</p> </div>
# ********************
# ...

# %%
text=soup.find(class_='widget-listing-content-section')
text=str(text)
print(text)
text[58:100]
# Out:
# <div class="widget-listing-content-section"> <h2><a href="https://www.aajtak.in/bihar/story/newly-married-woman-strangled-to-death-in-bihar-absconds-after-leaving-her-in-laws-house-lclcn-1859172-2024-01-14" title="बिहार: नवविवाहिता की गला दबाकर हत्या, ससुराल वाले घर छोड़कर फरार">बिहार: नवविवाहिता की गला दबाकर हत्या, ससुराल वाले घर छोड़कर फरार</a></h2> <h5>14 जनवरी 2024</h5> <p>पटना में एक नवविवाहित की गला दबाकर हत्या कर दी गई. मृतक के परिजनों ने आरोप लगाया कि रविवार को उन्हें सूचना मिली कि उनकी बेटी की मौत हो गई है, जबकि शनिवार की रात में ही बेटी से बात हुई थी. वह बहुत रो रही थी. मृतक के परिजन जब दामाद के घर पहुंचे, तो ससुराल के सभी सदस्य घर छोड़ कर फरार हो गए थे.</p> </div>
# 'https://www.aajtak.in/bihar/story/newly-ma'

# %%
start='href="'
end='" title'
pattern=re.escape(start) + r'(.?)' + re.escape(end)
re.findall(pattern,text,re.DOTALL)
# Out:
# []

# %%
pattern=r'htt'
for i in soup.find_all(class_='widget-listing-content-section'):
    print(i)
# Out:
# <div class="widget-listing-content-section"> <h2><a href="https://www.aajtak.in/bihar/story/newly-married-woman-strangled-to-death-in-bihar-absconds-after-leaving-her-in-laws-house-lclcn-1859172-2024-01-14" title="बिहार: नवविवाहिता की गला दबाकर हत्या, ससुराल वाले घर छोड़कर फरार">बिहार: नवविवाहिता की गला दबाकर हत्या, ससुराल वाले घर छोड़कर फरार</a></h2> <h5>14 जनवरी 2024</h5> <p>पटना में एक नवविवाहित की गला दबाकर हत्या कर दी गई. मृतक के परिजनों ने आरोप लगाया कि रविवार को उन्हें सूचना मिली कि उनकी बेटी की मौत हो गई है, जबकि शनिवार की रात में ही बेटी से बात हुई थी. वह बहुत रो रही थी. मृतक के परिजन जब दामाद के घर पहुंचे, तो ससुराल के सभी सदस्य घर छोड़ कर फरार हो गए थे.</p> </div>
# ...

# %%
start=text.find('href="')+6
end=text.find('" title')
print(start)
print(end)
print(text[start:end])
link=text[start:end]
# Out:
# 58
# 205
# https://www.aajtak.in/bihar/story/newly-married-woman-strangled-to-death-in-bihar-absconds-after-leaving-her-in-laws-house-lclcn-1859172-2024-01-14

# %%
#start=text.find('href="')+6
#end=text.find('" title')
#link=text[start:end]
res=rq.get(link)
html=res.text
soup=bsp(html,'html.parser')
for i in soup.find_all('p'):
    print(i.text)
# Out:
# Feedback
# बिहार के पटना में एक नवविवाहित की गला दबाकर हत्या कर दी गई. हत्या के बाद ससुराल वाले घर छोड़कर फरार हो गए. सूचना मिलते ही मौके पर पहुंची पुलिस ने शव को कब्जे में लेकर पोस्टमार्टम के लिए नालंदा मेडिकल कॉलेज भेज दिया. साथ ही मृतक के परिजनों के शिकायत पर पुलिस ने हत्या का एफआईआर दर्ज की है. पुलिस का कहना है कि मामले में जांच शुरू कर दी गई है.
# मामला गौरीचक थाना क्षेत्र के अलावलपुर गांव का है. यहां के रहने वाले 22 साल के सचिन कुमार की शादी नालंदा जिले के रहने वाले दीनानाथ कुमार की 19 साल की बेटी पूजा कुमारी से मई 2023 में हुई थी. पूजा कुमारी के परिजनों ने बताया कि शादी के बाद से ही दहेज के लिए पूजा कुमारी के ससुराल वाले उसके साथ मारपीट करते थे.
# कई बार ससुराल पक्ष को समझाने का प्रयास किया
# परिजनों का ये भी आरोप है कि कई बार उन लोगों ने ससुराल पक्ष को समझाने का प्रयास किया. मगर, वे लोग मानने को तैयार नहीं थे. पूजा के परिजनों ने आरोप लगाया कि रविवार को उन्हें सूचना मिली कि उनकी बेटी की मौत हो गई है, जबकि शनिवार की रात में ही पूजा से बात हुई थी.
# ...

# %%
for i in soup.find_all(class_='widget-listing-content-section'):
    text=str(i)
    start=text.find('href="')+6
    end=text.find('" title')
    print('*'*10)
    print(text[start:end])

# %%
start=text.find('href="')+6
end=text.find('" title')
link=text[start:end]

# %%
#IOPub data rate exceeded.
#The notebook server will temporarily stop sending output
#to the client in order to avoid crashing it.
#To change this limit, set the config variable
#`--NotebookApp.iopub_data_rate_limit`.

#Current values:
#NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
#NotebookApp.rate_limit_window=3.0 (secs)
import time
import random
time.sleep(random.uniform(1,3))

# %%
s=0
res=rq.get('https://www.aajtak.in/bihar')
html=res.text
soup=bsp(html,'html.parser')
for i in soup.find_all(class_='widget-listing-content-section'):
    s+=1
    time.sleep(0.0001)
    text=str(i)
    start=text.find('href="')+6
    end=text.find('" title')
    link=text[start:end]
    #print(link)
    
    res=rq.get(link)
    html=res.text
    sp=bsp(html,'html.parser')
    print(s,'**'*10)
    print(link)
    print(sp.find('h'))
    for j in sp.find_all('p'):
        print(j.text)
# Out:
# 1 ********************
# https://www.aajtak.in/uttar-pradesh/story/ram-temple-vhp-working-president-alok-kumar-ayodhya-ram-mandir-ntc-1859163-2024-01-14
# None
# Feedback
# राम मंदिर को लेकर समाज और लोगों को एकजुट करने में जुटा विश्व हिंदू परिषद के नेशनल वर्किंग प्रेसीडेंट राजधानी दिल्ली के लाजपत नगर में सिंधी समाज के कार्यक्रम में बोले कि 'लगातार सिंध से आने वाले समाचार चिंता करते हैं. वहां जो लोग रहते हैं उनका जीवन सुरक्षित नहीं है. उनकी संपत्ति सुरक्षित नहीं है. उनकी बेटियां सुरक्षित नहीं है. विरोध यातना प्रताड़ना को सहते हुए भी. अपने धर्म को बचाकर जो जी रहे हैं. उनको  प्रणाम कहना चाहिए.
# ...
